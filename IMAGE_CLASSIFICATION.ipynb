# %% [markdown]
# **DEEP LEARNING ALGORITHM
#  FOR MONUMENT IDENTIFICATION**
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# > This algorithm will help us to detect the
# image and give information about the objects  .
#
# > It will  detect various
# objects located insidr the picture given by user.

# %% [markdown]
# **CONVOLUTIONAL NEURAL NETWORK**
#
# CNN is a deep forward artifical neural network .
# CNN is a type of deep learning model for processing data that has a grid pattern.
# The four important layers in CNN are:
#
# 1. Convolution layer.
# 2. ReLU layer.
# 3. Pooling layer.
# 4. Fully connected layer.

# %% [markdown]
# How does CNN work step by step?****
#
#
#
# Step 1: Choose a Dataset. ...
# Step 2: Prepare Dataset for Training. ...
# Step 3: Create Training Data. ...
# Step 4: Shuffle the Dataset. ...
# Step 5: Assigning Labels and Features. ...
# Step 6: Normalising X and converting labels to categorical data. ...
# Step 7: Split X and Y for use in CNN

# %% [markdown]
# ** CONVOLUTIONAL NEURAL NETWORKS **
#
#
#
#
# *   AlexNet
#
# *  GoogleNet
#
# *   MobileNet
#
# *  VGGNet

# %% [markdown]
# ** TOOLS WE NEED **
#
#
# *  Packages of multiple libraries and IDEs
# *  IDEs
# *  Jupyter notebook
# *  VS Code

# %% [markdown]
# ** LIBRARIES **
#
#
# *   Tensorflow
# *   OpenCV
# *   NumPy
# *   Keras

# %% [markdown]
# **TENSORFLOW**
#
# TensorFlow is a free and open-source software library for machine learning and artificial intelligence. It can be used across a range of tasks but has a particular focus on training and inference of deep neural networks.

# %% [markdown]
# **OPENCV**
#
# OpenCV is a library of programming functions mainly aimed at real-time computer vision. Originally developed by Intel, it was later supported by Willow Garage then Itseez. The library is cross-platform and free for use under the open-source Apache 2 License.

# %% [markdown]
# **NUMPY**
#
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays

# %% [markdown]
# **KERAS**
#
# Keras is an open-source software library that provides a Python interface for artificial neural networks. Keras acts as an interface for the TensorFlow library. Up until version 2.3, Keras supported multiple backends, including TensorFlow, Microsoft Cognitive Toolkit, Theano, and PlaidML

# %% [markdown]
# **MOBILE NET**
#
#
# We are going to use mobilenet network.
# MobileNet is a type of convolutional neural network designed for mobile and embedded vision applications. They are based on a streamlined architecture that uses depthwise separable convolutions to build lightweight deep neural networks that can have low latency for mobile and embedded devices.

# %%
 import tensorflow as tf
 import numpy as np

# %%
filename='/content/various-objects-vector-1095259.jpg'

# %%
from IPython.display import Image
Image(filename='/content/various-objects-vector-1095259.jpg' , width=224,height=224)

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17225924/17225924 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size= (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 839ms/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step

# %%
print(results)
# Out:
# [[('n04116512', 'rubber_eraser', 0.3136371), ('n02807133', 'bathing_cap', 0.12643078), ('n04372370', 'switch', 0.117956065), ('n03602883', 'joystick', 0.10356373), ('n03532672', 'hook', 0.061954305)]]

# %%
plt.imshow(img)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n04116512', 'rubber_eraser', 0.3136371), ('n02807133', 'bathing_cap', 0.12643078), ('n04372370', 'switch', 0.117956065), ('n03602883', 'joystick', 0.10356373), ('n03532672', 'hook', 0.061954305)]]

# %%
##INDIA GATE
filename='India_Gate_44.jpg'

# %%
from IPython.display import Image
Image(filename='India_Gate_44.jpg' , width=224,height=224)

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size= (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 105ms/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
results=imagenet_utils.decode_predictions(predictions)
# Out:
# [[('n02825657', 'bell_cote', 0.40965617), ('n04486054', 'triumphal_arch', 0.2677772), ('n03781244', 'monastery', 0.009437696), ('n02814860', 'beacon', 0.009131668), ('n04266014', 'space_shuttle', 0.008435327)]]

# %%
##CHARMINAR
filename='charminar_71.jpg'
A

# %%
Image(filename='India_Gate_44.jpg' , width=224,height=224)

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17225924/17225924 [==============================] - 0s 0us/step

# %%
img=image.load_img(filename,target_size= (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 87ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n04523525', 'vault', 0.16701023), ('n02825657', 'bell_cote', 0.071337655), ('n04486054', 'triumphal_arch', 0.065090746), ('n03781244', 'monastery', 0.0541245), ('n04458633', 'totem_pole', 0.035262287)]]

# %%
##TAJ MAHAL
filename='Taj_mahal_75.jpg'

# %%
img=image.load_img(filename,target_size= (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 235ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03788195', 'mosque', 0.75057584), ('n03220513', 'dome', 0.015711604), ('n03877845', 'palace', 0.013801858), ('n03781244', 'monastery', 0.005722506), ('n03837869', 'obelisk', 0.0029015231)]]

# %%
 import tensorflow as tf
 import numpy as np

# %%
#konark temple
filename='Konark_temp_55.jpg'
##input

# %%
from IPython.display import Image
Image(filename='Konark_temp_55.jpg' , width=224,height=224)

##setting image height and width
##importing our image

# %%
mobile=tf.keras.applications.mobilenet_v2.MobileNetV2()
##MobileNetV2 is very similar to the original MobileNet, except that it uses inverted residual blocks with bottlenecking features. It has a drastically lower parameter count than the original MobileNet.
## MobileNets support any input size greater than 32 x 32, with larger image sizes offering better performance.

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size= (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
predictions= mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step

# %%
print(results)
# Out:
# [[('n03781244', 'monastery', 0.5307734), ('n03220513', 'dome', 0.069266714), ('n02825657', 'bell_cote', 0.06526374), ('n03877845', 'palace', 0.046883825), ('n03028079', 'church', 0.0288221)]]
